# %%
import datetime
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
# import pandas.io.data
import numpy as np
from matplotlib import pyplot as plt
import sys
import sompylib.sompy as SOM

pd.__version__
# %matplotlib inline
# import  pysparse
from pylab import matshow, savefig
from scipy.linalg import norm
import time
# from IPython.html.widgets import *
from ipywidgets import interact, HTML, FloatSlider
import time
import os

# %%
t = time.localtime()
date = str(t.tm_year)+"_"+str(t.tm_mon)+"_"+str(t.tm_mday)
print (date)
# Out:
# 2019_4_2

# %%
# path= '/Users/SVM/Dropbox/Applications/Crawlers/homegate/rent_listings.csv'
# listing = pd.read_csv(path)


# Zip_path = '/Users/SVM/Dropbox/Applications/realmatch360/Data/CH_Zip.csv'
# lon_lat =pd.read_csv(Zip_path)

# listing['Z_lat']= np.empty(listing.shape[0])
# listing['Z_lon']= np.empty(listing.shape[0])
# for i in range(listing.shape[0]):
#     try:
#         ind = lon_lat['zip']==listing['ZIP'].values[i]
#         listing['Z_lon'].values[i] = lon_lat['lon'].ix[ind].values
#         listing['Z_lat'].values[i] = lon_lat['lat'].ix[ind].values
#     except:
#         continue
# listing.to_csv(path_or_buf=path,index=False)

# %%
# Put files into separate folders
import os
import shutil
base_dir = "/USB_Disk_Ubuntu/Crawlers/HG_DB_20190213/"
rent_base_dir = 'homegate_rent/'
buy_base_dir = 'homegate_buy/'
filenames = os.listdir(base_dir + 'All/')

for fn in filenames[:]:
    if "buy" in fn:
#         print (fn)
        source = base_dir+'All/'+fn
        destination = base_dir+buy_base_dir+fn
        if 'latest' in fn:
            print (fn)
        else:
            shutil.move(source, destination)
            
            
    if 'rent' in fn:
#         print (fn)
        source = base_dir+'All/'+fn
        destination = base_dir+rent_base_dir+fn
        if 'latest' in fn:
            print (fn)
        else:
            shutil.move(source, destination)

# %%
import os
import sqlite3
import pandas.io.sql as sql
DBPath = base_dir+ rent_base_dir
CSVPath = base_dir+ 'homegate_rent_csv/'
cur_csv = []
for filename in os.listdir(CSVPath):
    if filename != '.DS_Store':
#         con = sqlite3.connect(DBPath+filename)
        cur_csv.append(filename.replace('.csv',""))
#         table = sql.read_sql_query('select * from listings',con)
#         table.to_csv(CSVPath+filename+'.csv',encoding='utf-8')
len(cur_csv)
# cur_csv[:10]
# Out:
# 6267

# %%
import os
import sqlite3
import pandas.io.sql as sql
# DBPath = '/All_Files/Applications/Crawlers/homegate/DB/sql_rental_DB_20170223/'
# CSVPath = '/All_Files/Applications/Crawlers/homegate/DB/CSV_rental_DB_20170223/'
count = 0
for i, filename in enumerate(os.listdir(DBPath)[:]):
    if filename != '.DS_Store':
        
        try:
            if filename in cur_csv:
                if i%100==0:
                    print (i, 'repeated')
                
                continue
                
            else:
                if i%100==0:
                    print (i)
                con = sqlite3.connect(DBPath+filename)
                table = sql.read_sql_query('select * from listings',con)
                table.to_csv(CSVPath+filename+'.csv',encoding='utf-8',index=False) 
                
        except:
            pass
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200

# %% [markdown]
# # Geo Coding Engine

# %%
Swiss_latlng = pd.read_csv('CH_WGS_84.csv',sep=';')
print (Swiss_latlng.shape)
Swiss_latlng = Swiss_latlng.dropna()
print (Swiss_latlng.shape)
Swiss_latlng.head()
# Out:
# (2114098, 15)
# (1996218, 15)
#           X          Y    EGID  EDID GDEKT  GDENR GDENAME             STRNAME  \
# 0  8.039432  47.393552  520001     0    AG   4001   Aarau  Schiffländestrasse
# 1  8.039034  47.393487  520002     0    AG   4001   Aarau  Schiffländestrasse
# 2  8.039447  47.392478  520003     0    AG   4001   Aarau           Pfrundweg
# 3  8.039665  47.392482  520004     0    AG   4001   Aarau           Pfrundweg
# 4  8.039266  47.392791  520005     0    AG   4001   Aarau           Pfrundweg
#
#   DEINR  PLZ4  PLZZ PLZNAME        GKODE        GKODN STRSP
# 0    43  5000     0   Aarau  2645359.617  1249365.315    de
# 1    45  5000     0   Aarau  2645329.670  1249357.809    de
# 2     4  5000     0   Aarau  2645361.719  1249245.885    de
# 3     6  5000     0   Aarau  2645378.130  1249246.448    de
# 4    10  5000     0   Aarau  2645347.749  1249280.588    de

# %%
# Text normalizing
import unidecode
# 
for field in ['GDENAME','STRNAME','PLZNAME']:
    vals = Swiss_latlng[field].values[:]
    for i in range(vals.shape[0]):
#         try:
        vals[i] = unidecode.unidecode(vals[i])
#         except:
#             print(vals[i])
    Swiss_latlng[field]=vals

# %%
ind_zip = Swiss_latlng.loc[Swiss_latlng.PLZNAME == 'Lausanne', 'PLZNAME'].index[:]
Swiss_latlng.ix[ind_zip]
Add_DF = Swiss_latlng.ix[ind_zip][['STRNAME','DEINR','PLZ4','GDENAME','PLZNAME']]
Add_DF.head()
# Out:
#                                 STRNAME DEINR  PLZ4        GDENAME   PLZNAME
# 1524170  Avenue Francois-Alphonse Forel   201  1015  Ecublens (VD)  Lausanne
# 1596265                   Route du Mont    60  1018       Lausanne  Lausanne
# 1596266              Route du Chatelard    50  1018       Lausanne  Lausanne
# 1596267              Route du Chatelard   50a  1018       Lausanne  Lausanne
# 1596268              Route du Chatelard   50b  1018       Lausanne  Lausanne

# %%
import os
import sqlite3
import pandas.io.sql as sql
DBPath = base_dir+ rent_base_dir
CSVPath = base_dir+ 'homegate_rent_csv/'
all_csvs = []
for filename in os.listdir(CSVPath):
    if filename != '.DS_Store':
        all_csvs.append(filename)
len(all_csvs)
# Out:
# 6267

# %%
#Fuzzy text matching
from fuzzywuzzy import fuzz
def get_ratio(row):
    name = STRNAME
    name1 = row['STRNAME']
    return fuzz.token_set_ratio(name, name1)




import unidecode
for i in range(3639,len(all_csvs)):
# for i in range(3):
    success = 0
    counter = 0
    sample_csv = pd.read_csv(CSVPath+all_csvs[i].replace('._',''))
    Xs = []
    Ys = []
    PLZ4s = []
    print (i,sample_csv.shape[0])
    for j in range(sample_csv.shape[0])[:]:
        Add = sample_csv[['Address']].values[j][0]
        Add = unidecode.unidecode(Add).split()
        try:
            PLZ4 = int(Add[-2])
            try:
                DEINR =  str(Add[-3].replace('/',' ').replace('-',' ').split(' ')[0])
            except:
                DEINR = -9999
            try:
                STRNAME = ' '.join(Add[:-3])
            except:
                STRNAME = 'UNKNOWN'
        except:
            try:
                PLZ4 = int(Add[-3])
                try:
                    DEINR =  str(Add[-4].replace('/',' ').replace('-',' ').split(' ')[0])
                except:
                    DEINR = -9999
                try:
                    STRNAME = ' '.join(Add[:-4])
                except:
                    STRNAME = 'UNKNOWN'
            except:
                PLZ4 = -9999
        
        try:
            DEINR= str(int(Add[0].replace(',','')))
        except:
            pass
        
        try:
            GDENAME = Add[-1].split('-')[-1]
        except:
            GDENAME = 'UNKNOWN'
        
        
        PLZ4s.append(PLZ4)
        ind = Swiss_latlng.loc[(Swiss_latlng["PLZ4"] == PLZ4)
#                                    & (Swiss_latlng["STRNAME"] == STRNAME)
                               & (Swiss_latlng["DEINR"] == DEINR)]
        if ind.shape[0]>0:
            fuzzy_sim = ind.apply(get_ratio, axis=1).sort_values(ascending=False)
#             a.values[0]
    #         sel= ind[ind.apply(get_ratio, axis=1) > 70]
            if fuzzy_sim.values[0]>70:
                res = ind[['X','Y','STRNAME','DEINR','PLZ4','GDENAME']].ix[fuzzy_sim.index[0]]
                
                Xs.append(res['X'])
                Ys.append(res['Y'])
#                 print (res.values[:])
#                 print (STRNAME,DEINR,PLZ4,GDENAME)
#                 print (sample_csv[['Address']].values[j][0])
#                 print (fuzz.token_set_ratio(res['STRNAME'], STRNAME))
#                 print ("")
                success+=1
            else:
#                 print ('f')
#                 print (DEINR,PLZ4)
#                 print (sample_csv[['Address']].values[j][0])
#                 print ('f')
                Xs.append(np.nan)
                Ys.append(np.nan)
        else:
#             print ('f')
#             print (DEINR,PLZ4)
#             print (sample_csv[['Address']].values[j][0])
#             print ('f')
            Xs.append(np.nan)
            Ys.append(np.nan)
        
        counter +=1
    
    print (success/float(counter+0.00001))

    sample_csv['X'] = Xs
    sample_csv['Y'] = Ys
    sample_csv['True_ZIP'] = PLZ4s
    
    sample_csv.to_csv(CSVPath+all_csvs[i].replace('._',''),index=False)
#     print (all_csvs[i].replace('._',''))
# Out:
# 3639 187
# 0.7754010280534209
# 3640 150
# 0.7866666142222257
# 3641 218
# 0.7706421664843043
# 3642 74
# 0.7702701661797072
# 3643 21
# 0.8571424489797862
# 3644 38
# 0.31578939058173927
# 3645 11
# 0.45454504132268975
# 3646 352
# 0.7982954318666071
# 3647 72
# 0.5416665914351956
# 3648 253
# 0.6837944393757138
# 3649 166
# 0.6686746585135748
# 3650 129
# 0.7519379262063622
# 3651 262
# 0.7786259244799266
# 3652 96
# 0.6770832628038268
# 3653 185
# 0.8216215772096445
# 3654 45
# 0.7777776049383099
# 3655 13
# 0.7692301775152481
# 3656 27
# 0.33333320987658893
# 3657 26
# 0.3461537130178027
# 3658 247
# 0.8582995603927304
# 3659 57
# 0.5789472668513567
# 3660 81
# 0.8148147142204056
# 3661 343
# 0.74344021156151
# 3662 175
# 0.8399999520000028
# 3663 206
# 0.7135921983693108
# 3664 0
# 0.0
# 3665 0
# 0.0
# 3666 0
# 0.0
# 3667 0
# 0.0
# 3668 0
# 0.0
# 3669 0
# 0.0
# 3670 0
# 0.0
# 3671 0
# 0.0
# 3672 365
# 0.756164362844812
# 3673 110
# 0.7727272024793452
# 3674 23
# ...

# %%
CSVPath+all_csvs[0].replace('._','')
# Out:
# '/Volumes/UBUNTU/HG_DB_20190213/homegate_rent_csv/1_homegatedb_2017-07-09-13-12rent.sqlite.csv'

# %% [markdown]
# # Cleaning the data sets

# %%
#TO join all the ads from different dates
unq_ids = set()
ids  = []
all_listings = pd.DataFrame()

for i , filename in enumerate(os.listdir(CSVPath)):
    if (filename != '.DS_Store') and ('rent' in filename):
        try:
            listing = pd.read_csv(CSVPath+filename.replace('._',''))
            ids = ids + list(listing['ID'].values[:])
            all_listings = pd.concat((listing,all_listings))
            listing.head()
        except:
            print (filename)
        if i%200 == 0:
            print ('After reading {} csv files: {} ids and all in one csv with the size of {} '.format(i,len(ids),all_listings.shape[0]))
# Out:
# After reading 0 csv files: 144 ids and all in one csv with the size of 144
# After reading 200 csv files: 26207 ids and all in one csv with the size of 26207
# After reading 400 csv files: 43385 ids and all in one csv with the size of 43385
# After reading 600 csv files: 56489 ids and all in one csv with the size of 56489
# After reading 800 csv files: 91837 ids and all in one csv with the size of 91837
# After reading 1000 csv files: 116593 ids and all in one csv with the size of 116593
# After reading 1200 csv files: 142695 ids and all in one csv with the size of 142695
# After reading 1400 csv files: 152879 ids and all in one csv with the size of 152879
# After reading 1600 csv files: 159618 ids and all in one csv with the size of 159618
# After reading 1800 csv files: 162194 ids and all in one csv with the size of 162194
# After reading 2000 csv files: 169887 ids and all in one csv with the size of 169887
# ...

# %%
filename.replace('._','')
# Out:
# '5_homegatedb_2019-02-12-19-48rent.sqlite.csv'

# %%
all_listings.head()
# Out:
#            ID   ZIP        Date                            Address  \
# 0   109623557  8123  12.02.2019  Zürichstrasse 109 8123 Ebmatingen
# 1  2147680414  8126  12.02.2019    In der Gandstr. 27 8126 Zumikon
# 2  2147680674  8126  12.02.2019          Ankenbüel 17 8126 Zumikon
# 3  2147680670  8126  12.02.2019           Ankenbüel 5 8126 Zumikon
# 4   109623847  8126  12.02.2019        Dorfstrasse 41 8126 Zumikon
#
#            Type  Rooms Floor  Living space  Floor space Room height   ...     \
# 0     Apartment    3.5    2.           NaN          NaN         NaN   ...
# 1     Apartment    2.5   NaN          60.0          NaN         NaN   ...
# 2     Apartment    2.5    2.          81.0          NaN         NaN   ...
# 3     Apartment    4.5    1.         115.0          NaN         NaN   ...
# 4  Single house    8.0   NaN         400.0          NaN         NaN   ...
#
#    Kindergarten  Primary school  Secondary school Motorway Floorplan  \
# ...

# %%
 # Categorical : Do nothing now
#         ['View', 'Balcony / Patio', 'Fireplace', 'Cable TV',
#        'ISDN connection', 'Children welcome', 'Parking place', 'Garage',
#        'Has wheelchair access', 'Pets allowed', 'Elevator',
#        'Group living arrangement', 'Upper ground floor', 'New building',
#        'Old building', 'Minergie construction', 'Minergie certified',
#        'Swimming pool', 'Location',
#         ]
        
# Garbage collection 
# Numerical fields
def makefloat(v):
    try:
        return float(str(v).replace('.–',''))
    except:
        return np.nan

for f in ['Rooms','Living space','Floor space', 'Room height', 'Volume', 'Year built',
        'Last renovation', 'Net rent', 'Additional expenses', 'Rent',
        'Public transport', 'Shopping','Kindergarten', 'Primary school', 'Secondary school', 'Motorway',
                'X', 'Y']:
    vals = all_listings[f].values[:]
    
    vals = [makefloat(v) for v in vals]
    all_listings[f] = vals
    
    
    
try:
    all_listings.loc[all_listings.Floor =='GF', 'Floor'] = 0
    all_listings.loc[all_listings.Floor =='Underground', 'Floor'] = -1
except:
    print ('floor is not in the columns')



# Fix this : Swap day and months    
# Addind year and months
# all_listings['Date'] = pd.DatetimeIndex(all_listings.Date)
# all_listings['yer'] = pd.DatetimeIndex(all_listings.Date).year
# all_listings['mnth'] = pd.DatetimeIndex(all_listings.Date).month


# for i in range(listing_with_latlong.shape[0]):
all_listings['mnth'] = [int(str(dt).split('.')[1]) for dt in all_listings['Date'].values[:]]
# true_d = [int(str(dt).split('.')[0]) for dt in all_listings['Date'].values[:]]
all_listings['yer'] = [int(str(dt).split('.')[2]) for dt in all_listings['Date'].values[:]]

# %%
sv_path = base_dir + 'all_rental_listings_cleaned_geocoded_'+date+'_.csv'
all_listings.to_csv(sv_path,index=False)

# %%
all_listings.shape
# Out:
# (643161, 51)

# %%
base_dir
# Out:
# '/USB_Disk_Ubuntu/Crawlers/HG_DB_20190213/'

# %%
# until here, it was enough on 20190215

# %%
# Abit of edit for the older data sets comes next: Just for once
# TODO later

# %%
# path = '/All_Files/Applications/Crawlers/homegate/DB/rental_DB/homegatedb__'+'all_latlng_complete'+'rent.csv'
path ='/All_Files/Applications/Crawlers/homegate/DB/All_Listing_latlng_2017_2_23.txt'

# base_dir = "/Volumes/UBUNTU/HG_DB_20190213/"

# path = base_dir + 'all_rental_listings_cleaned_geocoded_2019_2_15_.csv'


listing_with_latlong_old = pd.read_csv(path)
print (listing_with_latlong_old.shape)
listing_with_latlong_old.head()
# Out:
# (158171, 20)
#             ID                             Address     ZIP        Date  \
# 0  106322589.0  Reutlingerstrasse 10/14 5000 Aarau  5000.0  2017-02-22
# 1  106250068.0      Rue de Monthoux 40 1201 Genève  1200.0  2017-02-22
# 2  106330306.0      Rue de Berne 29bis 1201 Genève  1200.0  2017-02-22
# 3  106181244.0      Rue de Monthoux 40 1201 Genève  1200.0  2017-02-22
# 4  105931148.0          Rue de Bâle 16 1201 Genève  1200.0  2017-02-22
#
#         Type  Rooms Floor  Living space  Floor space Room height  Volume  \
# 0  Apartment    2.0    1.          42.0          NaN         NaN     NaN
# 1  Apartment    2.0    2.           NaN          NaN         NaN     NaN
# 2  Apartment    3.0    4.           NaN          NaN         NaN     NaN
# 3  Apartment    2.0    2.           NaN          NaN         NaN     NaN
# 4  Apartment    3.0    4.           NaN          NaN         NaN     NaN
#
#    Year built  Last renovation Net rent Additional expenses    Rent  \
# ...

# %%
listing_with_latlong_old['X'] = listing_with_latlong_old['lng'].values[:].copy()
listing_with_latlong_old['Y'] = listing_with_latlong_old['lat'].values[:].copy()
listing_with_latlong_old.drop(columns=['lat','lng'])
listing_with_latlong_old.head()
# Out:
#             ID                             Address     ZIP        Date  \
# 0  106322589.0  Reutlingerstrasse 10/14 5000 Aarau  5000.0  2017-02-22
# 1  106250068.0      Rue de Monthoux 40 1201 Genève  1200.0  2017-02-22
# 2  106330306.0      Rue de Berne 29bis 1201 Genève  1200.0  2017-02-22
# 3  106181244.0      Rue de Monthoux 40 1201 Genève  1200.0  2017-02-22
# 4  105931148.0          Rue de Bâle 16 1201 Genève  1200.0  2017-02-22
#
#         Type  Rooms Floor  Living space  Floor space Room height    ...      \
# 0  Apartment    2.0    1.          42.0          NaN         NaN    ...
# 1  Apartment    2.0    2.           NaN          NaN         NaN    ...
# 2  Apartment    3.0    4.           NaN          NaN         NaN    ...
# 3  Apartment    2.0    2.           NaN          NaN         NaN    ...
# 4  Apartment    3.0    4.           NaN          NaN         NaN    ...
#
#    Last renovation  Net rent  Additional expenses    Rent    Available  \
# ...

# %%
listing_with_latlong_old['lat']
# Out:
# 0         47.382578
# 1         46.210998
# 2         46.210495
# 3         46.210998
# 4         46.212934
# 5         46.209628
# 6         46.211280
# 7         46.207288
# 8         46.213396
# 9         46.210183
# 10        46.213460
# 11        46.209552
# 12        46.209628
# 13        46.210160
# 14        46.207935
# 15        46.208393
# 16        46.207687
# 17        46.210094
# 18        46.210668
# 19        46.207291
# 20        46.210081
# 21        46.216082
# 22        46.209552
# 23        46.522172
# 24        46.530645
# 25        46.528765
# 26        46.521806
# 27        46.522172
# 28        46.522172
# 29        46.532994
#             ...
# 158141    47.666238
# 158142    47.562115
# 158143    47.558781
# 158144    47.562043
# 158145    47.198793
# 158146    47.203124
# 158147    47.204783
# 158148    47.192830
# 158149    47.198274
# 158150    47.206353
# 158151    47.207471
# 158152    47.208313
# 158153    47.128280
# 158154    47.128280
# ...

# %%
 # Categorical : Do nothing now
#         ['View', 'Balcony / Patio', 'Fireplace', 'Cable TV',
#        'ISDN connection', 'Children welcome', 'Parking place', 'Garage',
#        'Has wheelchair access', 'Pets allowed', 'Elevator',
#        'Group living arrangement', 'Upper ground floor', 'New building',
#        'Old building', 'Minergie construction', 'Minergie certified',
#        'Swimming pool', 'Location',
#         ]
        
# Garbage collection 
# Numerical fields
def makefloat(v):
    try:
        return float(str(v).replace('.–',''))
    except:
        return np.nan

for f in ['Rooms','Living space','Floor space', 'Room height', 'Volume', 'Year built',
        'Last renovation', 'Net rent', 'Additional expenses', 'Rent',
        'Public transport', 'Shopping','Kindergarten', 'Primary school', 'Secondary school', 'Motorway',
                'X', 'Y']:
    vals = all_listings[f].values[:]
    
    vals = [makefloat(v) for v in vals]
    all_listings[f] = vals
    
    
    
try:
    all_listings.loc[all_listings.Floor =='GF', 'Floor'] = 0
    all_listings.loc[all_listings.Floor =='Underground', 'Floor'] = -1
except:
    print ('floor is not in the columns')

    
# Addind year and months
all_listings['Date'] = pd.DatetimeIndex(all_listings.Date)
all_listings['yer'] = pd.DatetimeIndex(all_listings.Date).year
all_listings['mnth'] = pd.DatetimeIndex(all_listings.Date).month

# %%
#TO join all the ads from different dates
unq_ids = set()



ids  = []
all_listings = pd.DataFrame()


# CSVPath = '/All_Files/Applications/Crawlers/homegate/DB/Asof20161005_CSV/'
for filename in os.listdir(CSVPath):
    if (filename != '.DS_Store') and ('rent' in filename):
        
        listing = pd.read_csv(CSVPath+filename)
    
        #Kinds of features we are interested in
        cols = ['ID','Address', 'ZIP', 'Date','Type','Rooms','Floor',
           'Living space','Floor space','Room height','Volume',
           'Year built','Last renovation','Net rent','Additional expenses',
           'Rent','Available']
#                 ,'Public transport','Shopping','Kindergarten','Primary school','Secondary school','Motorway']
        listing = listing[cols]

        #Types of listing we are interested in
        Types = ['Apartment','Attic compartment','Attic flat','Bachelor flat','Bifamiliar house','Cellar compartment','Chalet',
               'Duplex','Farm house','Granny flat','Home','Roof flat','Row house','Rustic house','Single house','Studio','Terrace flat',
               'Terrace house','Villa']
    
    #     Types = ['Apartment','Duplex','Home','Single house','Studio']
        id_type = []
        for i in range(listing.shape[0]):
            if listing['Type'].values[i] in Types:
                id_type.append(i)
        listing = listing.ix[id_type]
    
        ids.append(list(listing['ID'].values[:]))
        all_listings = pd.concat((listing,all_listings))
        listing.head()
        print listing.shape
# Out:
# (25668, 17)
# (24276, 17)
# (24472, 17)
# (13503, 17)
# (24965, 17)
# (24521, 17)
# (24372, 17)
# (23889, 17)
# (25234, 17)
# (25319, 17)
# (24675, 17)
# (24285, 17)
# (25695, 17)
# (24668, 17)
# (25001, 17)
# (25706, 17)
# (24260, 17)
# (6649, 17)
# (25422, 17)
# (25598, 17)
# (20206, 17)
# (24574, 17)
# (25061, 17)
# (25631, 17)
# (25496, 17)
# (25272, 17)
# (25925, 17)
# (25152, 17)
# (25441, 17)
# (24875, 17)
# (24957, 17)
# (25300, 17)
# (24754, 17)
# (25588, 17)
# (24815, 17)
# (25836, 17)
# (25451, 17)
# (25704, 17)
# (25184, 17)
# (25039, 17)
# (24882, 17)
# (25793, 17)
# (24676, 17)
# (25686, 17)
# (24922, 17)
# (25659, 17)
# (26122, 17)
# (25332, 17)
# (25794, 17)
# (24582, 17)
# (25722, 17)
# (25446, 17)
# (25361, 17)
# (24871, 17)
# (26020, 17)
# (25832, 17)
# (25671, 17)
# (24633, 17)
# (25950, 17)
# (26232, 17)
# (24869, 17)
# (26064, 17)
# (19922, 17)
# (24421, 17)
# (25141, 17)
# (24916, 17)
# (25949, 17)
# (0, 17)
# (25708, 17)
# (25814, 17)
# (26081, 17)
# ...

# %%
all_listings.shape
# Out:
# (3394022, 17)

# %%
np.unique(all_listings['ZIP'].values[:]).shape
# Out:
# (2147,)

# %%
# #TO join all the ads from different dates
# unq_ids = set()
# dates = ['24.05.2016','28.05.2016','01.06.2016','04.06.2016','07.06.2016','09.06.2016','14.06.2016','22.06.2016','24.06.2016','29.06.2016','01.07.2016','04.07.2016']
# ids  = []
# all_listings = pd.DataFrame()
# for d in dates:
#     path = '/Users/SVM/Dropbox/Applications/Crawlers/homegate/DB/rental_DB/homegatedb__'+d+'rent.csv'
#     listing = pd.read_csv(path)
    
#     #Kinds of features we are interested in
#     cols = ['ID','Address', 'ZIP', 'Date','Type','Rooms','Floor',
#        'Living space','Floor space','Room height','Volume',
#        'Year built','Last renovation','Net rent','Additional expenses',
#        'Rent','Available','Public transport','Shopping','Kindergarten','Primary school','Secondary school','Motorway']
#     listing = listing[cols]

#     #Types of listing we are interested in
#     Types = ['Apartment','Attic compartment','Attic flat','Bachelor flat','Bifamiliar house','Cellar compartment','Chalet',
#            'Duplex','Farm house','Granny flat','Home','Roof flat','Row house','Rustic house','Single house','Studio','Terrace flat',
#            'Terrace house','Villa']

# #     Types = ['Apartment','Duplex','Home','Single house','Studio']
#     id_type = []
#     for i in range(listing.shape[0]):
#         if listing['Type'].values[i] in Types:
#             id_type.append(i)
# #     listing = listing.ix[id_type]
    
#     ids.append(list(listing['ID'].values[:]))
#     all_listings = pd.concat((listing,all_listings))
#     listing.head()
#     print listing.shape

# %%
# diffs= []
# for i, idd in enumerate(ids[1:]):
#     s1 = set(list(ids[i-1]))
#     s2 = set(list(idd))
#     if i>1:
#         diffs.append(len(s2.difference(s1)))
#         print len(s2.difference(s1))

# %%
# np.median(np.asarray(diffs[:-1]))

# %%
# #TO join all the ads from different dates
# dates = ['24.05.2016','28.05.2016','01.06.2016','04.06.2016','07.06.2016','09.06.2016','14.06.2016','22.06.2016','24.06.2016','29.06.2016','01.07.2016','04.07.2016']
# ids  = []
# all_listings = pd.DataFrame()
# for d in dates:
#     path = '/Users/SVM/Dropbox/Applications/Crawlers/homegate/DB/rental_DB/homegatedb__'+d+'rent.csv'
#     listing = pd.read_csv(path)
    
#     #Kinds of features we are interested in
#     cols = ['ID','Address', 'ZIP', 'Date','Type','Rooms','Floor',
#        'Living space','Floor space','Room height','Volume',
#        'Year built','Last renovation','Net rent','Additional expenses',
#        'Rent','Available','Public transport','Shopping','Kindergarten','Primary school','Secondary school','Motorway']
#     listing = listing[cols]

#     #Types of listing we are interested in
#     # Types = ['Apartment','Attic compartment','Attic flat','Bachelor flat','Bifamiliar house','Cellar compartment','Chalet',
#     #        'Duplex','Farm house','Granny flat','Home','Roof flat','Row house','Rustic house','Single house','Studio','Terrace flat',
#     #        'Terrace house','Villa']

#     Types = ['Apartment','Duplex','Home','Single house','Studio']
#     id_type = []
#     for i in range(listing.shape[0]):
#         if listing['Type'].values[i] in Types:
#             id_type.append(i)
#     listing = listing.ix[id_type]
#     ids = ids + list(listing['ID'].values[:])
#     all_listings = pd.concat((listing,all_listings))
#     listing.head()
#     print listing.shape

# %%
all_listings['Date'] = pd.to_datetime(all_listings['Date'],format="%d.%m.%Y")
all_listings = all_listings.sort_values('Date',ascending=False)
print all_listings.shape
all_listings.head()
# Out:
# (3394022, 17)
#                ID                             Address     ZIP       Date  \
# 3     106322589.0  Reutlingerstrasse 10/14 5000 Aarau  5000.0 2017-02-22
# 7185  106250068.0      Rue de Monthoux 40 1201 Genève  1200.0 2017-02-22
# 7187  106330306.0      Rue de Berne 29bis 1201 Genève  1200.0 2017-02-22
# 7188  106181244.0      Rue de Monthoux 40 1201 Genève  1200.0 2017-02-22
# 7189  105931148.0          Rue de Bâle 16 1201 Genève  1200.0 2017-02-22
#
#            Type  Rooms Floor  Living space  Floor space Room height  Volume  \
# 3     Apartment    2.0    1.          42.0          NaN         NaN     NaN
# 7185  Apartment    2.0    2.           NaN          NaN         NaN     NaN
# 7187  Apartment    3.0    4.           NaN          NaN         NaN     NaN
# 7188  Apartment    2.0    2.           NaN          NaN         NaN     NaN
# 7189  Apartment    3.0    4.           NaN          NaN         NaN     NaN
#
# ...

# %%
all_listings.index = range(all_listings.shape[0])
all_listings.head()
# Out:
#             ID                             Address     ZIP       Date  \
# 0  106322589.0  Reutlingerstrasse 10/14 5000 Aarau  5000.0 2017-02-22
# 1  106250068.0      Rue de Monthoux 40 1201 Genève  1200.0 2017-02-22
# 2  106330306.0      Rue de Berne 29bis 1201 Genève  1200.0 2017-02-22
# 3  106181244.0      Rue de Monthoux 40 1201 Genève  1200.0 2017-02-22
# 4  105931148.0          Rue de Bâle 16 1201 Genève  1200.0 2017-02-22
#
#         Type  Rooms Floor  Living space  Floor space Room height  Volume  \
# 0  Apartment    2.0    1.          42.0          NaN         NaN     NaN
# 1  Apartment    2.0    2.           NaN          NaN         NaN     NaN
# 2  Apartment    3.0    4.           NaN          NaN         NaN     NaN
# 3  Apartment    2.0    2.           NaN          NaN         NaN     NaN
# 4  Apartment    3.0    4.           NaN          NaN         NaN     NaN
#
#    Year built  Last renovation Net rent Additional expenses    Rent  \
# ...

# %%
# Zurich_Zip = pd.read_csv("/All_Files/Applications/Crawlers/homegate/DB/Zurich_Zip.csv")
# Zurich_Zip.head()

# %%
# sel = [i for i in all_listings.index.values[:] if all_listings.ZIP.values[i] in Zurich_Zip.zip.values[:]]

# %%
# all_listings.ix[sel[0]]

# %%
# lates_listing_latlng = pd.read_csv("/All_Files/Applications/Crawlers/homegate/DB/rental_DB/homegatedb__all_latlng_completerent_latest.csv")
# print lates_listing_latlng.shape
# lates_listing_latlng.head()

# %%
# Zurich_Listing = all_listings.ix[sel]
all_listings.shape
# Out:
# (3394022, 17)

# %%
uniq_ids = np.unique(all_listings.ID)
uniq_ids.shape
# Out:
# (165431,)

# %%
all_listings.ix[all_listings.ID==uniq_ids[1000]]
# Out:
#                   ID                             Address     ZIP       Date  \
# 1872210  105239877.0  Schufelistrasse 7 8863 Buttikon SZ  8863.0 2016-11-01
# 1889610  105239877.0  Schufelistrasse 7 8863 Buttikon SZ  8863.0 2016-10-29
# 1926207  105239877.0  Schufelistrasse 7 8863 Buttikon SZ  8863.0 2016-10-27
# 1984336  105239877.0  Schufelistrasse 7 8863 Buttikon SZ  8863.0 2016-10-20
# 1991659  105239877.0  Schufelistrasse 7 8863 Buttikon SZ  8863.0 2016-10-17
# 2014439  105239877.0  Schufelistrasse 7 8863 Buttikon SZ  8863.0 2016-10-15
# 2048183  105239877.0  Schufelistrasse 7 8863 Buttikon SZ  8863.0 2016-10-11
# 2061919  105239877.0  Schufelistrasse 7 8863 Buttikon SZ  8863.0 2016-10-09
# 2104830  105239877.0  Schufelistrasse 7 8863 Buttikon SZ  8863.0 2016-10-05
# 2124285  105239877.0  Schufelistrasse 7 8863 Buttikon SZ  8863.0 2016-10-04
# 2135307  105239877.0  Schufelistrasse 7 8863 Buttikon SZ  8863.0 2016-10-01
# ...

# %%
all_listings = all_listings.drop_duplicates('ID',keep='first')
print all_listings.shape
all_listings.head()
# Out:
# (165431, 17)
#             ID                             Address     ZIP       Date  \
# 0  106322589.0  Reutlingerstrasse 10/14 5000 Aarau  5000.0 2017-02-22
# 1  106250068.0      Rue de Monthoux 40 1201 Genève  1200.0 2017-02-22
# 2  106330306.0      Rue de Berne 29bis 1201 Genève  1200.0 2017-02-22
# 3  106181244.0      Rue de Monthoux 40 1201 Genève  1200.0 2017-02-22
# 4  105931148.0          Rue de Bâle 16 1201 Genève  1200.0 2017-02-22
#
#         Type  Rooms Floor  Living space  Floor space Room height  Volume  \
# 0  Apartment    2.0    1.          42.0          NaN         NaN     NaN
# 1  Apartment    2.0    2.           NaN          NaN         NaN     NaN
# 2  Apartment    3.0    4.           NaN          NaN         NaN     NaN
# 3  Apartment    2.0    2.           NaN          NaN         NaN     NaN
# 4  Apartment    3.0    4.           NaN          NaN         NaN     NaN
#
#    Year built  Last renovation Net rent Additional expenses    Rent  \
# ...

# %%
all_listings.to_csv('/All_Files/Applications/Crawlers/homegate/DB/All_Listing_'+date+'.txt',index=False)

# %% [markdown]
# ## Cleaning

# %%
import os

lines = open(os.path.join(os.getcwd(), '/All_Files/Applications/Crawlers/homegate/DB/All_Listing_'+date+'.txt'), 'r').readlines()
for i,line in enumerate(lines):
    lines[i] = line.replace(".â€“","").replace(".–","").replace("Ã¼","u").replace("Ã¶","o").replace("Ã¤","a").replace("Ã©","e") \
    .replace("Ã¨","e").replace("Ã«","e").replace("Ã¯","i").replace("Ã¢","a").replace("Ãª","e").replace("Ã®","i") \
    .replace("Ã„ussere","").replace("Ãœ","u").replace("Ã´","o").replace("ÌÏ","u")

path = '/All_Files/Applications/Crawlers/homegate/DB/All_Listing_'+date+'.txt'
fh = open(path,'w') 
fh.writelines(lines) 
fh.close()

# %%
all_listings = pd.read_csv('/All_Files/Applications/Crawlers/homegate/DB/All_Listing_'+date+'.txt')
print all_listings.shape
all_listings.head()
# Out:
# (165431, 17)
#             ID                             Address     ZIP        Date  \
# 0  106322589.0  Reutlingerstrasse 10/14 5000 Aarau  5000.0  2017-02-22
# 1  106250068.0      Rue de Monthoux 40 1201 Genève  1200.0  2017-02-22
# 2  106330306.0      Rue de Berne 29bis 1201 Genève  1200.0  2017-02-22
# 3  106181244.0      Rue de Monthoux 40 1201 Genève  1200.0  2017-02-22
# 4  105931148.0          Rue de Bâle 16 1201 Genève  1200.0  2017-02-22
#
#         Type  Rooms Floor  Living space  Floor space Room height  Volume  \
# 0  Apartment    2.0    1.          42.0          NaN         NaN     NaN
# 1  Apartment    2.0    2.           NaN          NaN         NaN     NaN
# 2  Apartment    3.0    4.           NaN          NaN         NaN     NaN
# 3  Apartment    2.0    2.           NaN          NaN         NaN     NaN
# 4  Apartment    3.0    4.           NaN          NaN         NaN     NaN
#
#    Year built  Last renovation Net rent Additional expenses  Rent    Available
# ...

# %%
ind_by = all_listings['Rent']=='by request' 
all_listings['Rent'].ix[ind_by] =np.nan

ind_by = all_listings['Rent']=='EUR 2635' 
all_listings['Rent'].ix[ind_by] =np.nan

ind_by = all_listings['Rent']=='AUD 2960' 
all_listings['Rent'].ix[ind_by] =np.nan

ind_by = all_listings['Rent']=='EUR 800' 
all_listings['Rent'].ix[ind_by] =np.nan

ind_by = all_listings['Rent']=='EUR 1428' 
all_listings['Rent'].ix[ind_by] =np.nan


ind_by = all_listings['Rent']=='BGN 1630' 
all_listings['Rent'].ix[ind_by] =np.nan


ind_by = all_listings['Rent']=='EUR 469000' 
all_listings['Rent'].ix[ind_by] =np.nan

ind_by = all_listings['Rent']=='EUR 2091' 
all_listings['Rent'].ix[ind_by] =np.nan

ind_by = all_listings['Rent']=='EUR 912' 
all_listings['Rent'].ix[ind_by] =np.nan

ind_by = all_listings['Rent']=='EUR 939' 
all_listings['Rent'].ix[ind_by] =np.nan

ind_by = all_listings['Rent']=='BIF 2265' 
all_listings['Rent'].ix[ind_by] =np.nan

ind_by = all_listings['Rent']=='ANG 1750' 
all_listings['Rent'].ix[ind_by] =np.nan





all_listings['Rent'] = all_listings['Rent'].values[:].astype(float)

ind_by = all_listings['Rent']>30000 
all_listings['Rent'].ix[ind_by] =np.nan

ind_by = all_listings['Rent'] < 200 
all_listings['Rent'].ix[ind_by] =np.nan

ind_by = all_listings['Living space']<=10 
all_listings['Living space'].ix[ind_by] =np.nan

ind_by = all_listings['Rooms']> 15
all_listings['Rooms'].ix[ind_by] =np.nan

# %%
all_listings.shape
# Out:
# (165431, 17)

# %%
# GB = sample_listing_for_Vis.groupby(by='ZIP')
# analytics_ZIP_median = GB.median()
# analytics_ZIP_median['ZIP']= analytics_ZIP_median.index.values[:]
# analytics_ZIP_median

# %%
# path = '/All_Files/Applications/Crawlers/homegate/DB/rental_DB/analytics_ZIP_median.csv'
# analytics_ZIP_median.to_csv(path_or_buf=path,index=False)

# %%
# S_all_listings = all_listings.copy()

# %%
# listing = S_all_listings.copy()
# listing.shape

# %%
# # Just once
listing_with_latlong = all_listings.copy()
listing_with_latlong.columns
listing_with_latlong['lat'] = np.nan
listing_with_latlong['lng'] = np.nan
listing_with_latlong['URL'] = np.nan
# for i, r in enumerate(listing.values[:]):
#     listing_with_latlong['URL'].values[i] = "http://www.homegate.ch/rent/"+ str(listing_with_latlong['ID'].values[i])
    
    
path = '/All_Files/Applications/Crawlers/homegate/DB/All_Listing_latlng_'+date+'.txt'

listing_with_latlong.to_csv(path_or_buf=path,index=False)

# %% [markdown]
# # If stopped within geocoding step, start from here

# %% [markdown]
# # Geocoding

# %%
date
# Out:
# '2017_2_23'

# %%
date = '2017_2_23'
path = '/All_Files/Applications/Crawlers/homegate/DB/All_Listing_latlng_'+date+'.txt'
listing_with_latlong = pd.read_csv(path)
listing_with_latlong = listing_with_latlong.drop_duplicates()
indNAN = listing_with_latlong.ix[pd.isnull(listing_with_latlong['lat'])].index
batchsz = min(200,len(indNAN))
len(listing_with_latlong)
# Out:
# 158171

# %%
### thte geocoding procedure
import requests
import time

api_key = "AIzaSyAFXiV-CQes-RdHy7Z9zcZ5V3HhYL2dME8"  #this is for sevamoo
api_key = "AIzaSyDOu0j-2vubbIUyOkCYnswGFQVl233mnaQ"  #this is for python
# api_key = "AIzaSyD33fmn1Alnn571j1tbnPgX4dtn5whO5DI"
api_key = 'AIzaSyAZxQKDnp-tYZ2FT7gHdeoZrzTyFX8zSOY' #new one with the biiling enabled
api_key = 'AIzaSyC4S3v7TlzoWZLKmepd5GWeQ-4JpMJ67WU'

client_id = "585485872455-vll08msco5cn9k9tmij6eeqrm8gbj3ea.apps.googleusercontent.com"
# Xcoords = np.zeros(uniq_zipcodes.shape[0])
# Ycoords = np.zeros(uniq_zipcodes.shape[0])
googlecount = 0

path = '/All_Files/Applications/Crawlers/homegate/DB/All_Listing_latlng_'+date+'.txt'
listing_with_latlong = pd.read_csv(path)
listing_with_latlong = listing_with_latlong.drop_duplicates()
indNAN = listing_with_latlong.ix[pd.isnull(listing_with_latlong['lat'])].index
batchsz = min(200,len(indNAN))
print indNAN.shape[0]
while batchsz>0:
    path = '/All_Files/Applications/Crawlers/homegate/DB/All_Listing_latlng_'+date+'.txt'
    listing_with_latlong = pd.read_csv(path)
    listing_with_latlong = listing_with_latlong.drop_duplicates()
    listing_with_latlong.shape
    indNAN = listing_with_latlong.ix[pd.isnull(listing_with_latlong['lat'])].index
    print indNAN.shape[0]
    batchsz = min(200,len(indNAN))
    pos_res = 0
    for r in range(batchsz):
        i = indNAN[r]
        time.sleep(.1)
        address = str(listing_with_latlong["Address"].values[i])+' Switzerland'

        try:
            api_response = requests.get('https://maps.googleapis.com/maps/api/geocode/json?address={}&key={}'.format(address,api_key))
        #     api_response = requests.get('https://maps.googleapis.com/maps/api/geocode/json?address={0}&key={1}'.format(address, api_key))
            api_response_dict = api_response.json()
            if api_response_dict['status'] == 'OK':
                listing_with_latlong['lat'].values[i] = api_response_dict['results'][0]['geometry']['location']['lat']
                listing_with_latlong['lng'].values[i] = api_response_dict['results'][0]['geometry']['location']['lng']
                pos_res = pos_res + 1 
            else:
                listing_with_latlong['lat'].values[i] = 0.0
                listing_with_latlong['lng'].values[i] = 0.0
#                 print api_response_dict['status']
                if api_response_dict['status'] =='OVER_QUERY_LIMIT':
                    print 'waiting for a while....'
                    time.sleep(1800.)


            del api_response 
        except:
            print address
            listing_with_latlong['lat'].values[i] = 0.0
            listing_with_latlong['lng'].values[i] = 0.0
    print '{} out of {}'.format(pos_res,batchsz)
    googlecount = googlecount + batchsz
#     batchsz = 0
    listing_with_latlong.to_csv(path_or_buf=path,index=False)
# Out:
# 0

# %%
# ind_zero = listing_with_latlong['lat']==0.0
# listing_with_latlong['lat'].values[ind_zero] = np.nan
# listing_with_latlong['lng'].values[ind_zero] = np.nan

# %%
path = '/All_Files/Applications/Crawlers/homegate/DB/All_Listing_latlng_'+date+'.txt'
listing_with_latlong = pd.read_csv(path)
listing_with_latlong = listing_with_latlong.drop_duplicates()
indNAN = listing_with_latlong.ix[pd.isnull(listing_with_latlong['lat'])].index
len(indNAN)
# Out:
# 0

# %%
listing_with_latlong.shape
# Out:
# (158171, 20)

# %%
# path = '/Users/SVM/Dropbox/Applications/Crawlers/homegate/csv-to-json-converter-master/hg_ads.csv'
# path = '/Users/SVM/Dropbox/Applications/Crawlers/homegate/DB/rental_DB/homegatedb__'+'all_latlng'+'rent.csv'

listing_with_latlong = pd.read_csv(path)
listing_with_latlong.shape
# Out:
# (158171, 20)

# %%
 #remove coordinates errors
latbound = [45.81802,47.80838] 
lonbound = [5.95587,10.49203]
ind0 = listing_with_latlong['lat'].values[:]>latbound[1]
ind1 = listing_with_latlong['lat'].values[:]<latbound[0]
ind2 = listing_with_latlong['lng'].values[:]>lonbound[1]
ind3 = listing_with_latlong['lng'].values[:]<lonbound[0]
indremove = (ind0 + ind1 + ind2 + ind3)
indkeep = [not i for i in indremove]
print indremove.sum()
listing_with_latlong = listing_with_latlong.ix[indkeep]
listing_with_latlong.shape
# Out:
# 0
# (158171, 20)

# %%
listing_with_latlong.to_csv(path_or_buf=path,index=False)

# %%
listing_with_latlong.head()
# Out:
#             ID                             Address     ZIP        Date  \
# 0  106322589.0  Reutlingerstrasse 10/14 5000 Aarau  5000.0  2017-02-22
# 1  106250068.0      Rue de Monthoux 40 1201 Genève  1200.0  2017-02-22
# 2  106330306.0      Rue de Berne 29bis 1201 Genève  1200.0  2017-02-22
# 3  106181244.0      Rue de Monthoux 40 1201 Genève  1200.0  2017-02-22
# 4  105931148.0          Rue de Bâle 16 1201 Genève  1200.0  2017-02-22
#
#         Type  Rooms Floor  Living space  Floor space Room height  Volume  \
# 0  Apartment    2.0    1.          42.0          NaN         NaN     NaN
# 1  Apartment    2.0    2.           NaN          NaN         NaN     NaN
# 2  Apartment    3.0    4.           NaN          NaN         NaN     NaN
# 3  Apartment    2.0    2.           NaN          NaN         NaN     NaN
# 4  Apartment    3.0    4.           NaN          NaN         NaN     NaN
#
#    Year built  Last renovation Net rent Additional expenses    Rent  \
# ...

# %%
listing_with_latlong['URL'] = np.empty(listing_with_latlong.shape[0],dtype=str)
for i, r in enumerate(listing_with_latlong.values[:]):
#     print str(listing_with_latlong['ID'].values[i])
    listing_with_latlong['URL'].values[i] = "http://www.homegate.ch/rent/"+ str(listing_with_latlong['ID'].values[i].astype(float).astype(int))

# %%
listing_with_latlong = listing_with_latlong.dropna(subset=['lat','lng'])
listing_with_latlong = listing_with_latlong.dropna(subset=['ZIP'])

print listing_with_latlong.shape

path1 = '/All_Files/Applications/Crawlers/homegate/DB/All_Listing_latlng_'+date+'.csv'
# Out:
# (158171, 20)

# %%
listing_with_latlong.head()
# Out:
#             ID                             Address     ZIP        Date  \
# 0  106322589.0  Reutlingerstrasse 10/14 5000 Aarau  5000.0  2017-02-22
# 1  106250068.0      Rue de Monthoux 40 1201 Genève  1200.0  2017-02-22
# 2  106330306.0      Rue de Berne 29bis 1201 Genève  1200.0  2017-02-22
# 3  106181244.0      Rue de Monthoux 40 1201 Genève  1200.0  2017-02-22
# 4  105931148.0          Rue de Bâle 16 1201 Genève  1200.0  2017-02-22
#
#         Type  Rooms Floor  Living space  Floor space Room height  Volume  \
# 0  Apartment    2.0    1.          42.0          NaN         NaN     NaN
# 1  Apartment    2.0    2.           NaN          NaN         NaN     NaN
# 2  Apartment    3.0    4.           NaN          NaN         NaN     NaN
# 3  Apartment    2.0    2.           NaN          NaN         NaN     NaN
# 4  Apartment    3.0    4.           NaN          NaN         NaN     NaN
#
#    Year built  Last renovation Net rent Additional expenses    Rent  \
# ...

# %% [markdown]
# # Load the lastest Crawl result and merge with geocoded data for the leaflet

# %%
CSVPath = '/All_Files/Applications/Crawlers/homegate/DB/CSV_rental_DB_20170223/'
all_dates = []
for filename in os.listdir(CSVPath):
    if (filename != '.DS_Store') and ('rent' in filename):
        filename = filename.replace('homegatedb__','').replace('rent.sqlite.csv','').replace('rent.csv','')
        all_dates.append(filename)
#         print filename

# %%
crawl_dates = pd.DataFrame(data=pd.to_datetime(all_dates),columns=['date'])
crawl_dates = crawl_dates.sort_values('date',ascending=False)
crawl_dates.head()
# Out:
#          date
# 54 2017-12-02
# 53 2017-12-01
# 50 2017-11-01
# 46 2017-10-02
# 45 2017-10-01

# %%
dd = np.datetime_as_string(crawl_dates.values[0])[0].replace('T00:00:00.000000000','').split('-')
dd
# Out:
# ['2017', '12', '02']

# %%
last_date = dd[1]+'.'+dd[2]+'.'+dd[0]
last_date
# Out:
# '12.02.2017'

# %%
path_last_date = CSVPath + 'homegatedb__'+last_date+'rent.sqlite.csv'
last_crawl = pd.read_csv(path_last_date)
last_crawl.shape
# Out:
# (42031, 47)

# %%
listing_with_latlong.index = listing_with_latlong.ID.values[:].astype(int)
last_crawl = listing_with_latlong.ix[last_crawl.ID.values[:]]
last_crawl = last_crawl.dropna(subset=['lat','lng'])
last_crawl.shape
# Out:
# (25194, 20)

# %%
# listing_with_latlong.index = listing_with_latlong.ID.values[:].astype(int)
# last_crawl.index = last_crawl.ID.values[:]
# last_crawl = pd.merge(last_crawl,listing_with_latlong[['ID','lat','lng','URL']],how='inner')
# last_crawl.shape

# %%
plt.plot(last_crawl.lng,last_crawl.lat,'.');

# %%
cols_in_map = ['Address','ZIP','Type','Rooms','Floor','Living space','Year built','Last renovation','Rent','Available','lat','lng','URL','ID']

# %%
latestCSVPath = '/All_Files/Applications/Crawlers/homegate/DB/hg_latest_rental_DB_20170223.csv'
last_crawl = last_crawl[cols_in_map]
print last_crawl.shape
last_crawl.to_csv(latestCSVPath,index=False)
# Out:
# (25194, 14)

# %%
a = [u'PCTApartment16032000_Apartment18032000.jpg', u'PCTApartment15012000_Apartment18032000.jpg', u'PCTApartment16032010_Apartment18032010.jpg', u'CHFApartment16032000_Apartment18032000.jpg', u'CHFApartment16032010_Apartment18032010.jpg', u'CHFApartment15012000_Apartment18032000.jpg']
b = 'PCTApartment16032000_Apartment18032000.jpg'
b in a
# Out:
# True

# %%
if b in a:
    print ('hi')
# Out:
# hi
